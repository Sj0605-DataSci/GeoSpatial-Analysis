# %%
import pandas as pd
import numpy as np
import folium
import geopy.distance

# %%
#Read file containing location details
df = pd.read_csv('https://drive.google.com/uc?id=19JERBe0ndadkMPKDFZ0rTEZqdI50zDfk')
df.head(10)
# Out:
#          lat        lng      store                                 address
# 0  40.711000 -74.000878  Starbucks        375 Pearl st, New York, NY 10038
# 1  40.707142 -74.004987  Starbucks     135 John Street, New York, NY 10038
# 2  40.708411 -74.007404  Starbucks  100 William Street, New York, NY 10038
# 3  40.711644 -74.006667  Starbucks     38 Park Row, #4, New York, NY 10038
# 4  40.710171 -74.007931  Starbucks   130 Fulton Street, New York, NY 10038
# 5  40.706316 -74.006582  Starbucks      80 Pine Street, New York, NY 10005
# 6  40.712208 -74.008192  Starbucks        233 Broadway, New York, NY 10279
# 7  40.708742 -74.009508  Starbucks   55 Liberty Street, New York, NY 10005
# 8  40.706033 -74.008348  Starbucks          60 Wall St, New York, NY 10005
# 9  40.704817 -74.007231  Starbucks         99 Wall St., New York, NY 10005

# %%
#Merge Columns
df['Coordinate'] = '(' + df['lat'].astype(str) + ', ' + df['lng'].astype(str) + ')'
df.head(10)
# Out:
#          lat        lng      store                                 address  \
# 0  40.711000 -74.000878  Starbucks        375 Pearl st, New York, NY 10038
# 1  40.707142 -74.004987  Starbucks     135 John Street, New York, NY 10038
# 2  40.708411 -74.007404  Starbucks  100 William Street, New York, NY 10038
# 3  40.711644 -74.006667  Starbucks     38 Park Row, #4, New York, NY 10038
# 4  40.710171 -74.007931  Starbucks   130 Fulton Street, New York, NY 10038
# 5  40.706316 -74.006582  Starbucks      80 Pine Street, New York, NY 10005
# 6  40.712208 -74.008192  Starbucks        233 Broadway, New York, NY 10279
# 7  40.708742 -74.009508  Starbucks   55 Liberty Street, New York, NY 10005
# 8  40.706033 -74.008348  Starbucks          60 Wall St, New York, NY 10005
# 9  40.704817 -74.007231  Starbucks         99 Wall St., New York, NY 10005
#
#                 Coordinate
# 0     (40.711, -74.000878)
# 1  (40.707142, -74.004987)
# 2  (40.708411, -74.007404)
# 3  (40.711644, -74.006667)
# 4  (40.710171, -74.007931)
# 5  (40.706316, -74.006582)
# 6  (40.712208, -74.008192)
# 7  (40.708742, -74.009508)
# 8  (40.706033, -74.008348)
# 9  (40.704817, -74.007231)

# %%
#New York Empire State Building Lat Long (Looking for any approx center point)
NY_coord = (40.748488, -73.985238)

# %% [markdown]
# **1. Compute the distance of the stores**

# %%
#Compute distance of every store from city center
distances_km = []

for row in df.itertuples(index=False):
   distances_km.append(
       geopy.distance.distance(NY_coord, row.Coordinate).km
   )

df['Distance'] = distances_km
df.head(10)
# Out:
#          lat        lng      store                                 address  \
# 0  40.711000 -74.000878  Starbucks        375 Pearl st, New York, NY 10038
# 1  40.707142 -74.004987  Starbucks     135 John Street, New York, NY 10038
# 2  40.708411 -74.007404  Starbucks  100 William Street, New York, NY 10038
# 3  40.711644 -74.006667  Starbucks     38 Park Row, #4, New York, NY 10038
# 4  40.710171 -74.007931  Starbucks   130 Fulton Street, New York, NY 10038
# 5  40.706316 -74.006582  Starbucks      80 Pine Street, New York, NY 10005
# 6  40.712208 -74.008192  Starbucks        233 Broadway, New York, NY 10279
# 7  40.708742 -74.009508  Starbucks   55 Liberty Street, New York, NY 10005
# 8  40.706033 -74.008348  Starbucks          60 Wall St, New York, NY 10005
# 9  40.704817 -74.007231  Starbucks         99 Wall St., New York, NY 10005
#
#                 Coordinate  Distance
# 0     (40.711, -74.000878)  4.367628
# 1  (40.707142, -74.004987)  4.885149
# 2  (40.708411, -74.007404)  4.828401
# 3  (40.711644, -74.006667)  4.474066
# 4  (40.710171, -74.007931)  4.666971
# 5  (40.706316, -74.006582)  5.018288
# 6  (40.712208, -74.008192)  4.471204
# 7  (40.708742, -74.009508)  4.866712
# 8  (40.706033, -74.008348)  5.102829
# 9  (40.704817, -74.007231)  5.193348

# %% [markdown]
# **2.Visualize data on a map**

# %%
#Empire State Building coordinates
m = folium.Map(location=[40.748488, -73.985238], zoom_start= 10)

#Place markers for the stores on the map
for i, row in df.iterrows():
  lat = df.at[i, 'lat']
  lng = df.at[i, 'lng']
  store = df.at[i, 'store']

  if store == 'McDonalds':
    color = 'blue'
  else:
    color = 'green'

  folium.Marker(location=[lat,lng], popup=store, icon= folium.Icon(color=color)).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf46d24622be0572e8fd363fd1d586e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf46d24622be0572e8fd363fd1d586e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_bf46d24622be0572e8fd363fd1d586e6 = L.map(
#                 &quot;map_bf46d24622be0572e8fd363fd1d586e6&quot;,
#                 {
#                     center: [40.748488, -73.985238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d49301b6adc258c864b7f3511b30cc04 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bf46d24622be0572e8fd363fd1d586e6);
#
#
#             var marker_a858671751af2dc6be6ed60a2d214224 = L.marker(
#                 [40.711, -74.000878],
#                 {}
#             ).addTo(map_bf46d24622be0572e8fd363fd1d586e6);
#
#
#             var icon_8c7720f78e0fd4549b9174a7fc726a18 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a858671751af2dc6be6ed60a2d214224.setIcon(icon_8c7720f78e0fd4549b9174a7fc726a18);
#
#
#         var popup_e274257da0df185a2b09054ed63feedc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_84b279448cd9e98408a53f78c8d48455 = $(`&lt;div id=&quot;html_84b279448cd9e98408a53f78c8d48455&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_e274257da0df185a2b09054ed63feedc.setContent(html_84b279448cd9e98408a53f78c8d48455);
#
#
#         marker_a858671751af2dc6be6ed60a2d214224.bindPopup(popup_e274257da0df185a2b09054ed63feedc)
#         ;
#
#
#
#
#             var marker_4d28c18c7b466e3638aa5b8b06667689 = L.marker(
#                 [40.707142, -74.004987],
#                 {}
#             ).addTo(map_bf46d24622be0572e8fd363fd1d586e6);
#
#
#             var icon_07a1441972a4dfcb131876c781df5365 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4d28c18c7b466e3638aa5b8b06667689.setIcon(icon_07a1441972a4dfcb131876c781df5365);
#
#
#         var popup_ccc3e25c2cce2581b9bc1460bbeda8eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4f1de7c934ab797a3c06a9be20a80c6f = $(`&lt;div id=&quot;html_4f1de7c934ab797a3c06a9be20a80c6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_ccc3e25c2cce2581b9bc1460bbeda8eb.setContent(html_4f1de7c934ab797a3c06a9be20a80c6f);
#
#
#         marker_4d28c18c7b466e3638aa5b8b06667689.bindPopup(popup_ccc3e25c2cce2581b9bc1460bbeda8eb)
#         ;
#
#
#
#
#             var marker_1b056670ce6213747013c54efefa93cf = L.marker(
#                 [40.708411, -74.007404],
#                 {}
#             ).addTo(map_bf46d24622be0572e8fd363fd1d586e6);
#
#
#             var icon_699d0aa28d7c0b122d77cdd86bd8008b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1b056670ce6213747013c54efefa93cf.setIcon(icon_699d0aa28d7c0b122d77cdd86bd8008b);
#
#
#         var popup_47ff5b948f25e50eb472d97564d8e18e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_092ca7a5a73cc81e162169a06418c5be = $(`&lt;div id=&quot;html_092ca7a5a73cc81e162169a06418c5be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_47ff5b948f25e50eb472d97564d8e18e.setContent(html_092ca7a5a73cc81e162169a06418c5be);
#
#
#         marker_1b056670ce6213747013c54efefa93cf.bindPopup(popup_47ff5b948f25e50eb472d97564d8e18e)
#         ;
#
#
#
#
#             var marker_899ed55f33ee077fe12f0ab9702fc8dc = L.marker(
#                 [40.711644, -74.006667],
#                 {}
#             ).addTo(map_bf46d24622be0572e8fd363fd1d586e6);
#
#
#             var icon_fb599d37dfe1c66a6bc9704183e26141 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_899ed55f33ee077fe12f0ab9702fc8dc.setIcon(icon_fb599d37dfe1c66a6bc9704

# %% [markdown]
# **3. Compute number of stores located in a given radius**

# %%
#All stores at a distance greater/less than x kms
df[df['Distance'] > 10]
# Out:
#            lat        lng      store  \
# 227  40.841350 -73.939822  Starbucks
# 228  40.841723 -73.941375  Starbucks
# 229  40.851000 -73.938421  Starbucks
# 230  40.865721 -73.927287  Starbucks
# 273  40.835319 -73.944335  McDonalds
# 277  40.842594 -73.938972  McDonalds
# 280  40.850094 -73.936035  McDonalds
# 286  40.865080 -73.927202  McDonalds
# 287  40.867396 -73.921301  McDonalds
#
#                                           address               Coordinate  \
# 227             4001 Broadway, New York, NY 10032   (40.84135, -73.939822)
# 228  177 Fort Washington Ave , New York, NY 10032  (40.841723, -73.941375)
# 229            803 W 181st St, New York, NY 10033     (40.851, -73.938421)
# 230             4761 Broadway, New York, NY 10040  (40.865721, -73.927287)
# 273                                 3809 BROADWAY  (40.835319, -73.944335)
# 277                                 4040 BROADWAY  (40.842594, -73.938972)
# 280                                 4259 BROADWAY  (40.850094, -73.936035)
# 286                                208 DYCKMAN ST   (40.86508, -73.927202)
# 287                         608 WEST 207TH STREET  (40.867396, -73.921301)
#
#       Distance
# 227  11.001594
# 228  10.995612
# 229  12.050055
# 230  13.906793
# 273  10.241912
# 277  11.156082
# 280  12.023104
# 286  13.842721
# 287  14.264323

# %% [markdown]
# **4. Compute the closest and farthest stores from Empire State Building**

# %%
df_farthest = df.iloc[df.groupby('store')['Distance'].agg(pd.Series.idxmax)]
df_closest = df.iloc[df.groupby('store')['Distance'].agg(pd.Series.idxmin)]
df_new = pd.concat([df_farthest, df_closest])

# %%
df_new
# Out:
#            lat        lng      store                               address  \
# 287  40.867396 -73.921301  McDonalds                 608 WEST 207TH STREET
# 230  40.865721 -73.927287  Starbucks     4761 Broadway, New York, NY 10040
# 256  40.750816 -73.986819  McDonalds                           972 6TH AVE
# 110  40.748660 -73.985614  Starbucks  350 Fifth Avenue, New York, NY 10118
#
#                   Coordinate   Distance
# 287  (40.867396, -73.921301)  14.264323
# 230  (40.865721, -73.927287)  13.906793
# 256  (40.750816, -73.986819)   0.290966
# 110   (40.74866, -73.985614)   0.037057

# %%
#Empire State Building coordinates
m = folium.Map(location=[40.748488, -73.985238], zoom_start= 10)

for i, rown in df_new.iterrows():
  lat = df_new.at[i, 'lat']
  lng = df_new.at[i, 'lng']
  store = df_new.at[i, 'store']

  if store == 'McDonalds':
    color = 'blue'
  else:
    color = 'green'

  folium.Marker(location=[lat,lng], popup=store, icon= folium.Icon(color=color)).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94c364d28cdaeffb79f425a4b8ed39de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94c364d28cdaeffb79f425a4b8ed39de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_94c364d28cdaeffb79f425a4b8ed39de = L.map(
#                 &quot;map_94c364d28cdaeffb79f425a4b8ed39de&quot;,
#                 {
#                     center: [40.748488, -73.985238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9eedf370d2471f042095897416c493a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_94c364d28cdaeffb79f425a4b8ed39de);
#
#
#             var marker_f2157abd09b21cb78fab58eadab2dfec = L.marker(
#                 [40.867396, -73.921301],
#                 {}
#             ).addTo(map_94c364d28cdaeffb79f425a4b8ed39de);
#
#
#             var icon_8ffb3fa8524705cdb45ae97195f360b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f2157abd09b21cb78fab58eadab2dfec.setIcon(icon_8ffb3fa8524705cdb45ae97195f360b1);
#
#
#         var popup_ca213725ca2a7401ee0647e7e4e4e7d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_583b6e8afe6000d16af8e19e3c7ee93b = $(`&lt;div id=&quot;html_583b6e8afe6000d16af8e19e3c7ee93b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonalds&lt;/div&gt;`)[0];
#             popup_ca213725ca2a7401ee0647e7e4e4e7d6.setContent(html_583b6e8afe6000d16af8e19e3c7ee93b);
#
#
#         marker_f2157abd09b21cb78fab58eadab2dfec.bindPopup(popup_ca213725ca2a7401ee0647e7e4e4e7d6)
#         ;
#
#
#
#
#             var marker_1ecaad804e57a5cdfde4200b3139ba25 = L.marker(
#                 [40.865721, -73.927287],
#                 {}
#             ).addTo(map_94c364d28cdaeffb79f425a4b8ed39de);
#
#
#             var icon_ad7710667d1cde4cc611612f96b305d3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1ecaad804e57a5cdfde4200b3139ba25.setIcon(icon_ad7710667d1cde4cc611612f96b305d3);
#
#
#         var popup_80434a1e84070cd63e6d7ed12914eeed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5ffa210feace72d86377b8ac9430a40d = $(`&lt;div id=&quot;html_5ffa210feace72d86377b8ac9430a40d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_80434a1e84070cd63e6d7ed12914eeed.setContent(html_5ffa210feace72d86377b8ac9430a40d);
#
#
#         marker_1ecaad804e57a5cdfde4200b3139ba25.bindPopup(popup_80434a1e84070cd63e6d7ed12914eeed)
#         ;
#
#
#
#
#             var marker_d26cba1758853efe2c8ae2a1a4d4afe0 = L.marker(
#                 [40.750816, -73.986819],
#                 {}
#             ).addTo(map_94c364d28cdaeffb79f425a4b8ed39de);
#
#
#             var icon_84973ddfd1fe43327326ef398f80da5e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d26cba1758853efe2c8ae2a1a4d4afe0.setIcon(icon_84973ddfd1fe43327326ef398f80da5e);
#
#
#         var popup_603f2b5271bde94b8c40df020e7787ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3f2e71126572831dd934f74e9973a4d7 = $(`&lt;div id=&quot;html_3f2e71126572831dd934f74e9973a4d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonalds&lt;/div&gt;`)[0];
#             popup_603f2b5271bde94b8c40df020e7787ae.setContent(html_3f2e71126572831dd934f74e9973a4d7);
#
#
#         marker_d26cba1758853efe2c8ae2a1a4d4afe0.bindPopup(popup_603f2b5271bde94b8c40df020e7787ae)
#         ;
#
#
#
#
#             var marker_dd0d5fde39797674dfa194141b52def8 = L.marker(
#                 [40.74866, -73.985614],
#                 {}
#             ).addTo(map_94c364d28cdaeffb79f425a4b8ed39de);
#
#
#             var icon_c020b0ce84f4453cc5d547fc431d7304 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dd0d5fde39797674dfa194141b52def8.setIcon(icon_c020b0ce84f4453cc5d547f
